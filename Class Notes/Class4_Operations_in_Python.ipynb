# %%
#

# %%
/ ---> float-div
// ----> floor div

# %% [markdown]
# # Comparision Operation

# %%
Comparision between value is done----> it only returns boolean( True , False)

# %%
< # lessthan
> # greater than
<= #  lessthan or Equal
>= #  greater than equals

# %%
20 < 40
# Out:
# True

# %%
==
!=

# %%
40 < 10
# Out:
# False

# %%
10 > 50
# Out:
# False

# %%
50 > 10
# Out:
# True

# %%
50 < 50
# Out:
# False

# %%
50 <= 50
# Out:
# True

# %%
50 >= 50
# Out:
# True

# %%
# Equality Operation

# %%
==
!=

# %%
10 == 10
# Out:
# True

# %%
a = 30 # assigning value

# %%
a == 40 # Checking for equality
# Out:
# False

# %%
a == 30
# Out:
# True

# %%
b = 70

# %%
b!= 70
# Out:
# False

# %%
b== 70
# Out:
# True

# %%
a = "python"
b = "python"

# %%
a
# Out:
# 'python'

# %%
b
# Out:
# 'python'

# %%
a == b
# Out:
# True

# %%
ASCII - American Standard Code for Information Interchange

# %% [markdown]
# ![image.png](attachment:bfd0cebe-8c24-4b8d-9a85-0459538ccf93.png)

# %%
ord("a")
# Out:
# 97

# %%
ord("p")
# Out:
# 112

# %%
c = "pythos"
d = "pythoz"

# %%
c == d
# Out:
# False

# %%
PYTHON , python

# %%
chr(97)
# Out:
# 'a'

# %%
chr(115)
# Out:
# 's'

# %% [markdown]
# # Logical operations

# %%
Gates
AND 
OR
NOT

# %%
and
or
not

# %% [markdown]
# ![image.png](attachment:7986b3f1-a164-46e3-98d0-810a8147faa1.png)

# %%
0-----> False
1 ----> True

# %%
and

# %%
False and False
False and True
True and False
True and True

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
a = 10
b = 20
if a==10 and b==20: # True
    print("Values match")
# Out:
# Values match

# %%
a = 10
b = 20
if a==45 and b==20: # False
    print("Values match")

# %%
10

# %%
True and True

# %%
 # a==45
False and True
# Out:
# False

# %%
or

# %%
False or False
False or True
True or False
True or True

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
not

# %%
True ----> False
False ---> True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
XOR

# %%
x = 44
y = 56

# %%
bin(44)
# Out:
# '0b101100'

# %%
bin(56)
# Out:
# '0b111000'

# %%
44---> 1 0 1 1 0 0
56---> 1 1 1 0 0 0
^
--------------------
010100

# %%
0b010100
# Out:
# 20

# %%
44 ^ 56
# Out:
# 20

# %%
a=5

b=7

print (a and b)
# Out:
# 7

# %%
10 and 20 # RHS value considered
# Out:
# 20

# %%
0 and 20# Considers 0  apart from value
# Out:
# 0

# %%
10 and 0
# Out:
# 0

# %%
30 or 50 # left value considered
# Out:
# 30

# %%
0 or 50 # Considers value apart from 0
# Out:
# 50

# %%
not 20 # ----> not True
# Out:
# False

# %%
not 0 # ----> not False
# Out:
# True

# %%
3 or 4 or 5 or 6
# Out:
# 3

# %%
bool(20)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
# Assignment operation(=)

# %%
a = 20
b = 80
c= 0

# %% [markdown]
# # Compounding operation

# %%
a = 10 + 20

# %%
incremental ++
decremental --

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a = a + 5 # -----> a = 10 + 5

# %%
a
# Out:
# 15

# %%
b = 10

# %%
b
# Out:
# 10

# %%
# compounding
b+=7 # ----> b = b+7
b-=7 # ----> b = b-7
b*=7 # ----> b = b*7
b/=7 # ----> b = b/7
b//=7 # ----> b = b//7
b%=7 # ----> b = b%7
b**=7 # ----> b = b**7

# %%
b
# Out:
# 17

# %%
b
# Out:
# 128.0

# %%
c = 100
c/=5

# %%
c = c/5
20.0

# %%
c
# Out:
# 20.0

# %%
d = 2
d**=3
# d = 2**3

# %%
d
# Out:
# 8

# %%
# Identity Operation ( gives True , false only)
is
is not

# %%
a = 10
b = 20
c = 30
print(a)
print(b)
print(c)
print(d)

# %% [markdown]
# ![image.png](attachment:08cb3ec6-9b8e-49e1-bdf7-252cfd2cabdb.png)

# %%
Memory Reusability/Object reusability

# %%
a = 10
b = 10

# %% [markdown]
# ![image.png](attachment:1a039bb2-bd9c-447e-8589-79b9e6e8bf76.png)

# %%
a = 20
b = 20

# %%
id(a)
# Out:
# 140736279424024

# %%
id(b)
# Out:
# 140736279424024

# %%
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
c = 50
d = 50

# %%
c is d
# Out:
# True

# %%
c is not d
# Out:
# False

# %%
What is thedifference between == and is

# %%
== -----> Value
is -----> address(id)

# %%
c = 50
d = 50

# %%
d = 90

# %%
d
# Out:
# 90

# %%
limitations of memory reusability
int ----> -5 to 255
float ---> it is not applicable
complex it is not applicable
string ---> applicable

# %%
a = 350
b = 350

# %%
id(a)
# Out:
# 2388718575440

# %%
id(b)
# Out:
# 2388718575568

# %%
a = 35.7
b = 35.7
print(id(a))
print(id(b))
# Out:
# 2388715877072
# 2388715880400

# %%
a is b
# Out:
# False

# %%
30 == 30
is

# %%
a = 3+4j
b = 3+4j
print(id(a))
print(id(b))
# Out:
# 2388718575088
# 2388718575696

# %%
a = "python"
b = "python"
print(id(a))
print(id(b))
# Out:
# 2388626799856
# 2388626799856

# %%
a = None
b = None
print(id(a))
print(id(b))

# %%
np--->np.isnull
--------------->df.isnull()

# %%
30
30
