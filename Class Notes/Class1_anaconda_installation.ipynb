# %% [markdown]
# # Download link - https://www.anaconda.com/download/success

# %%
print(10+20)
# Out:
# 30

# %% [raw]
# Heading1 ---> in raw cell

# %% [markdown]
# # Heading1 ---> in Markdown cell
# - point1
# - point2
