# %% [markdown]
# # Python

# %% [markdown]
# - Python is a high level , dynamically typed Programminng language

# %% [markdown]
# # What is Programminng language ?
# - Programminng language is  the meansof communication b/w Humans and Machines

# %%
a = 10

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# - high level
# - Middle level
# - low level

# %%
# High Level language
- easily understandable by Humans
ex -Python ,Java , C++.......

# %%
# low level
-  easily understandable by Machines
-ex - Assembly language , G code,Mcode

# %%
# Middle level
it's a balance b/w high level and low level
ex - C programming

# %%
typing
1 - dynamically typed
2 - Statically typed

# %%
# dynamically typed
a = 220000
python-----> automatically understand the data type

# %%
# Statically typed
int b;
b = 20
java, C ----->> externally define data type

# %% [markdown]
# # Why Python ?
# - Easy to learn----> syntax
# - Huge Libraries support ---> numpy pandas ,matlotlib....
# - Open Source ---> free
# - multipurpose ----> DS , Dev , AI ,IOT
# - Platform independence ---> Jupyter , colab ,vs code , pycharm ....

# %%
History
- 1980's
- Guido Van Rossum

# %%
import sys

# %%
print(dir(sys))
# Out:
# ['__breakpointhook__', '__displayhook__', '__doc__', '__excepthook__', '__interactivehook__', '__loader__', '__name__', '__package__', '__spec__', '__stderr__', '__stdin__', '__stdout__', '__unraisablehook__', '_base_executable', '_clear_type_cache', '_current_exceptions', '_current_frames', '_debugmallocstats', '_enablelegacywindowsfsencoding', '_framework', '_getframe', '_getframemodulename', '_git', '_home', '_setprofileallthreads', '_settraceallthreads', '_stdlib_dir', '_vpath', '_xoptions', 'activate_stack_trampoline', 'addaudithook', 'api_version', 'argv', 'audit', 'base_exec_prefix', 'base_prefix', 'breakpointhook', 'builtin_module_names', 'byteorder', 'call_tracing', 'copyright', 'deactivate_stack_trampoline', 'displayhook', 'dllhandle', 'dont_write_bytecode', 'exc_info', 'excepthook', 'exception', 'exec_prefix', 'executable', 'exit', 'flags', 'float_info', 'float_repr_style', 'get_asyncgen_hooks', 'get_coroutine_origin_tracking_depth', 'get_int_max_str_digits', 'getallocated
# ...

# %%
sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]'

# %%
import sys
sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # Execution of Python files

# %%
extension

# %%
1 - .py
2 - .ipynb

# %%
print("hello")
# Out:
# hello

# %%
print("World")
# Out:
# World

# %%
ways of execution
1 ---> Normal cell execution
2 ---> python Interpretor---> in the terminal
3 ---> Python file from terminal

# %%
10+20
# Out:
# 30

# %%
pwd
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\16 Feb'
