# %%
10 and 20
# Out:
# 20

# %%
10 or 20
# Out:
# 10

# %%
0 and 20
# Out:
# 0

# %% [markdown]
# # Float
# - any number with a decimal is float number

# %%
a = 80

# %%
b = 70.00003

# %%
type(b)
# Out:
# float

# %%
c = -9999.9999

# %%
type(c)
# Out:
# float

# %%
# Operations on Float
- Arithmatic operation
- Comparision operation
- Logical operation
- equality operation
- Assignment operation
- identity operation

# %%
10.2 and 3.5
# Out:
# 3.5

# %%
0 and 3.5
# Out:
# 0

# %%
a = 9.8
b = 9.8
# is , is not----> ID

# %%
a is b
# Out:
# False

# %%
id(a)
# Out:
# 1810894077904

# %%
id(b)
# Out:
# 1810896838640

# %%
Memory reusability ---> not applicable on float

# %%
c = 70
d = 70

# %%
# complex
- any number that  can b represented in the form of a+bj
where
a ----> real number
b----> Imaginary number

# %%
c = 2+5j

# %%
type(c)
# Out:
# complex

# %%
c = 54-66j

# %%
c
# Out:
# (54-66j)

# %%
c.real
# Out:
# 54.0

# %%
c.imag
# Out:
# -66.0

# %%
memory reusability----> Not applicable

# %%
2 +5j
------> +2
------> +5

# %%
60-3j

# %%
-3

# %%
# operations on complex number

# %%
a = -40+39J
b = 12-5j

# %%
a + b
# Out:
# (-28+34j)

# %%
-40+12
# Out:
# -28

# %%
-28

# %%
39-5
# Out:
# 34

# %%
-28+34j

# %%
# Operations on Complex
- Arithmatic operation
- Logical operation
- equality operation
- Assignment operation
- identity operation

Not Applicable
- Comparision operation

# %%
j = 29

# %%
22+9j
# Out:
# (22+9j)

# %%
j
# Out:
# 29

# %%
a
# Out:
# (-40+39j)

# %%
b
# Out:
# (12-5j)

# %%
a < b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 a < b
#
# TypeError: '<' not supported between instances of 'complex' and 'complex'

# %%
a == b
# Out:
# False

# %%
a
# Out:
# (-40+39j)

# %%
a ** 2
# Out:
# (79-3120j)

# %%
(2+3j) **2
# Out:
# (-5+12j)

# %%
(2+3j) * (2+3j)
# Out:
# (-5+12j)

# %%
boolean
True 
False

# %%
1 ----> True
0 ---> False

# %%
not 1
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
True + True
# Out:
# 2

# %%
False + True
# Out:
# 1

# %%
None

# %%
a = None

# %%
type(a)
# Out:
# NoneType

# %%
Memory reusability ---> None

# %%
None + None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 None +None
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
None > None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 None > None
#
# TypeError: '>' not supported between instances of 'NoneType' and 'NoneType'

# %%
# String
- Anything written inside
'' ----> single quote
"" ----> double quotes
''' ''' ---> Single triple quote
""" """ ---> double triple quotes
is a str

# %%
6547686 ----> int

# %%
'6547686'----> str

# %%
`this`

# %%
type(6547686)
# Out:
# int

# %%
type('6547686')
# Out:
# str

# %%
'python'

# %%
s = 'we are learning Python'
s
# Out:
# 'we are learning Python'

# %%
s1 = 'Today is Python's class'
s1
# Out:
#   Cell In[54], line 1
#     s1 = 'Today is Python's class'
#                                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s1 = "Today is Python's class"
s1
# Out:
# "Today is Python's class"

# %%
s1 = "Today is "Python" class"
s1
# Out:
#   Cell In[56], line 1
#     s1 = "Today is "Python" class"
#                     ^
# SyntaxError: invalid syntax

# %%
s1 = '''Today is "Python" class'''
s1
# Out:
# 'Today is "Python" class'

# %%
s1 = '''Today is 
"Python" class'''
print(s1)
# Out:
# Today is
# "Python" class

# %%
s1 = """Today is 
'''Python''' class"""
print(s1)
# Out:
# Today is
# '''Python''' class

# %%
'''
slkdjADJad
lkAXaxAXaxxqxqutwqdytqw
'''
a = 30
a+=5
s2
# Out:
# '\nslkdjADJad\nlkAXaxAXaxxqxqutwqdytqw\n'

# %%
"""" abcd """"
# Out:
#   Cell In[64], line 1
#     """" abcd """"
#                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# Type Casting
- converting one data type to anaother is called as type casting/type conversion

# %%
a = 7897
a
# Out:
# 7897

# %%
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 7897.0

# %%
type(a)
# Out:
# int

# %%
f = float(a)

# %%
f
# Out:
# 7897.0

# %%
type(f)
# Out:
# float

# %%
type(a)
# Out:
# int

# %%
a = float(a)
type(a)
# Out:
# float

# %%
a
# Out:
# 7897.0

# %%
99.88767

# %%
int(99.88767)
# Out:
# 99

# %%
[]
()

# %%
300 ---> 300.0

# %%
l = [1,2,3,4]

# %%
type(l)
# Out:
# list

# %%
(1,2,3,4)
# Out:
# (1, 2, 3, 4)

# %%
tuple(l)
# Out:
# (1, 2, 3, 4)

# %%
s = "1234.5657"

# %%
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 int(s)
#
# ValueError: invalid literal for int() with base 10: '1234.5657'

# %%
f = float(s)

# %%
f
# Out:
# 1234.5657

# %%
int(f)
# Out:
# 1234

# %%
s = "1234.5657"
int(float(s))
# Out:
# 1234

# %%
Just a unique case  tried it gave >>> 
bool("False")
True

# %%
 bool("")
# Out:
# False

# %%
 bool("False")
# Out:
# True

# %%
()

# %%
can we do type casting in multiple similar values at once like if we have 
a,b,c all have float values then can we do typecasting them together into int.

# %%
a = 99.0
b = 60.7
c = 95.66

lst = [99.0 , 60.7 , 95.66]
l = []
for i in lst:
    l.append(int(i))

# %%
l
# Out:
# [99, 60, 95]

# %%
>>> a =10.5
>>> b=20.5
>>> c=30.9
>>> a,b,c = int(a),int(b),int(c)

# %% [markdown]
# # Input and output function

# %%
# input

# %%
a = 10
b = 80
a+b
# Out:
# 90

# %%
20
30

# %%
existing_amount = 5000
# deposit
amt = input("Enter the amount you want to deposite---->")
# Out:
# Enter the amount you want to deposite----> 600

# %%
# Note - by default input() takes str as an input type

# %%
amt
# Out:
# '300'

# %%
existing_amount+amt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 existing_amount+amt
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
type(existing_amount)
# Out:
# int

# %%
type(amt)
# Out:
# str

# %%
a = input()
# Out:
#  676

# %%
type(a)
# Out:
# str

# %%
# typeecasting

# %%
existing_amount = 5000
# deposit
amt = int(input("Enter the amount you want to deposite---->"))
existing_amount = existing_amount+amt
print(existing_amount)
# Out:
# Enter the amount you want to deposite----> 400
# 5400

# %%
# Out:
# 5800

# %%
# eval

# %%
user_name = input("Enter the user name: ")
age =  input("""Enter the age: """)
# Out:
# Enter the user name:  abc
# Enter the age:  123

# %%
str
int

# %%
user_name  ----> str
age ----> str

# %%
w edont know what type of data user is gonna enter 
eval

# %%
user_name = eval(input("Enter the user name: "))
age =  eval(input("Enter the age: "))
age+=5
# Out:
# Enter the user name:  "Rambo"
# Enter the age:  25

# %%
user_name
# Out:
# 'Rambo'

# %%
age
# Out:
# 30

# %%
type(user_name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
val = eval(input("some "))
# Out:
# some  345

# %%
10+5*3
# Out:
# 25

# %%
val
# Out:
# 25

# %%
print(10+5*3)
# Out:
# 25

# %%
val
# Out:
# 345

# %%
bal = 345

# %%
-5 to 255

# %%
print(eval((input('enter the age'))))

# %%
age
# Out:
# 20

# %% [markdown]
# # Output

# %%
a = 10
b = 20
c= 30
a
# Out:
# 10

# %%
a = 10
b = 20
c= 30
a
b
# Out:
# 20

# %%
a = 10
b = 20
c= 30
c
print(a)
print(b)
# Out:
# 10
# 20

# %%
a = 10
b = 20
c= 30
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
"\n"

# %%
a = 10
b = 20
c= 30
print(a)
print(b)
print(c)

# %%
a = 10
b = 20
c= 30
print(a,b,c)
# Out:
# 10 20 30

# %%
a = 10
b = 20
c= 30
print(a,b,c,sep=" ")
# Out:
# 10 20 30

# %%
a = 10
b = 20
c= 30
print(a,b,c,sep="%%%%%%%%%%%%")
# Out:
# 10%%%%%%%%%%%%20%%%%%%%%%%%%30

# %%
a = 10
b = 20
c= 30
print(a)
print(b)
# Out:
# 10
# 20

# %%
a---> 10
b---> 20
c ---> 30
10
20

# %%
"\n" -----> new line

# %%
a = 10
b = 20
c=  30
print(a , end="++++++++++++")
print(b, end="*************")
print(c , end="^^^^^^^^^^^")
# Out:
# 10++++++++++++20*************30^^^^^^^^^^^

# %%
a---> 10
b---> 20
c ---> 30
10++++++++++++20*************30^^^^^^^^^^^

# %%
a = 10
b = 20
c=  30
print(a , end="--")
print(b, end="***")
print(c , end="^^")
# Out:
# 10--20***30^^

# %%
10--20***30^^

# %%
a = 10
b = 20
c=  30
print(a , end="\n")
print(b, end="\n")
print(c , end="\n")
# Out:
# 10
# 20
# 30

# %%
var = eval(input())
[2.2, 250 , "Usman"]
# Out:
#  [2.2, 250 , "Usman"]
# [2.2, 250, 'Usman']

# %%
var
# Out:
# [2.2, 250, 'Usman']

# %%
var = int(input())
# Out:
#  XMNnbx
