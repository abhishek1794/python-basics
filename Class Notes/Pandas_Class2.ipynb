# %%
pwd
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\16 Feb'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6CE9-051B
#
#  Directory of C:\Users\Lenovo\Desktop\16 Feb
#
# 30-03-2026  20:12    <DIR>          .
# 30-03-2026  20:12    <DIR>          ..
# 30-03-2026  20:12    <DIR>          .ipynb_checkpoints
# 16-03-2026  21:21    <DIR>          __pycache__
# 17-03-2026  22:41               109 abc.txt
# 03-03-2026  20:12             1,610 Class1_anaconda_installation.ipynb
# 03-03-2026  22:40            40,281 class10_list_comp_exercises.ipynb
# 05-03-2026  22:22            67,066 Class11_tuple_dict.ipynb
# 09-03-2026  22:33           110,932 Class12_dict_methods_set_Conditional_statements.ipynb
# 10-03-2026  22:42            44,586 Class13_loops.ipynb
# 11-03-2026  22:43         4,320,470 Class14_Functions.ipynb
# 17-03-2026  22:45            59,593 Class15_Functions_2.ipynb
# 16-03-2026  22:28           111,056 Class16_function_3_modules_FileHandling.ipynb
# 17-03-2026  22:42            64,164 Class17_File_Handling_2.ipynb
# ...

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
weather_data = pd.read_csv(r"datasets/weather_data.csv")

# %%
weather_data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# Attributes of DF

# %%
shape , size , dim

# %%
s = weather_data.shape
s
# Out:
# (6, 4)

# %%
weather_data.size
# Out:
# 24

# %%
weather_data.ndim
# Out:
# 2

# %%
type(s)
# Out:
# tuple

# %% [markdown]
# # head()
# - it displays top data from the DF(default 5 rows)

# %%
weather_data.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %% [markdown]
# # tail()
# - it displays bottom data from the DF(default 5 rows)

# %%
weather_data.tail()
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_data.head(20)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
weather_data.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %% [markdown]
# # columns

# %%
weather_data.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %% [markdown]
# # info()

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 324.0+ bytes

# %%
1 - column names
2 - dtype of col
3 - no of rows
4 - no of columns
5 - Null value
6 - Memory

# %%
	"1/1/2017"

# %%
my_d = {"year":pd.Series([1990, 1994,1998,2002,2004]),
    "country":pd.Series(["Italy" , "USA" , "France" , "Japan"]),
    "winner":pd.Series(["Germany" , "Brazil" , "France" , "India"]),
    }
my_DF = pd.DataFrame(my_d)

# %%
my_DF
# Out:
#    year country   winner
# 0  1990   Italy  Germany
# 1  1994     USA   Brazil
# 2  1998  France   France
# 3  2002   Japan    India
# 4  2004     NaN      NaN

# %%
my_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     5 non-null      int64
#  1   country  4 non-null      object
#  2   winner   4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
5- 4
# Out:
# 1

# %% [markdown]
# # Statistical Summary

# %%
weather_data.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
numerical column----> continuous data (Regression)
yes/no/Maybe-----> Categorical data (Classification)
2

# %%
weather_data.describe(include="all")
# Out:
#              day  temperature  windspeed event
# count          6     6.000000   6.000000     6
# unique         6          NaN        NaN     3
# top     1/1/2017          NaN        NaN  Rain
# freq           1          NaN        NaN     2
# mean         NaN    30.333333   4.666667   NaN
# std          NaN     3.829708   2.338090   NaN
# min          NaN    24.000000   2.000000   NaN
# 25%          NaN    28.750000   2.500000   NaN
# 50%          NaN    31.500000   5.000000   NaN
# 75%          NaN    32.000000   6.750000   NaN
# max          NaN    35.000000   7.000000   NaN

# %%
bike = pd.read_csv("datasets/citibike_tripdata.csv")

# %%
bike.head(20)
# Out:
#     tripduration            starttime             stoptime  start station id  \
# 0            338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1           1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2            232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3            190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4            303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5            176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6            577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7            830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8            395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9            170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
# 10           353  2018-05-01 05:18:36  2018-05-01 05:24:29              3225
# ...

# %% [markdown]
# # indexing and Slicing of Data Frame

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32428 entries, 0 to 32427
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tripduration         32428 non-null  int64
#  1   starttime            32428 non-null  object
#  2   stoptime             32428 non-null  object
#  3   start station id     32428 non-null  int64
#  4   start station name   32428 non-null  object
#  5   end station id       32428 non-null  int64
#  6   end station name     32428 non-null  object
#  7   bikeid               32428 non-null  int64
#  8   name_localizedValue  32428 non-null  object
#  9   usertype             32428 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 2.5+ MB

# %%
bike.describe()
# Out:
#         tripduration  start station id  end station id        bikeid
# count   32428.000000      32428.000000    32428.000000  32428.000000
# mean      798.978352       3264.568829     3255.485568  29817.647959
# std      9961.203954        137.810344      149.390306   2807.705863
# min        61.000000       3183.000000      212.000000  15271.000000
# 25%       236.000000       3192.000000     3186.000000  26310.000000
# 50%       352.000000       3206.000000     3203.000000  29516.000000
# 75%       590.000000       3272.000000     3270.000000  33568.000000
# max    936970.000000       3681.000000     3681.000000  33682.000000

# %%
# column
bike.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'end station id', 'end station name', 'bikeid',
#        'name_localizedValue', 'usertype'],
#       dtype='object')

# %%
# getting columns we want

# %%
time = bike[["starttime" , "stoptime"]]

# %%
time
# Out:
#                  starttime             stoptime
# 0      2018-05-01 00:04:47  2018-05-01 00:10:25
# 1      2018-05-01 01:31:10  2018-05-01 01:55:53
# 2      2018-05-01 01:31:29  2018-05-01 01:35:22
# 3      2018-05-01 02:03:29  2018-05-01 02:06:40
# 4      2018-05-01 04:27:12  2018-05-01 04:32:16
# ...                    ...                  ...
# 32423  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427  2018-05-30 13:50:58  2018-05-30 13:57:08
#
# [32428 rows x 2 columns]

# %%
bike
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
# at[]

# %%
print(bike.at[5 , "bikeid"])
# Out:
# 29298

# %%
print(bike.to_string())
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
bike.at[4 , "bikeid"]
# Out:
# np.int64(15271)

# %%
bike.at[4 , "bikeid"] = 9999999

# %%
bike
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %% [markdown]
# # Slicing Methods onn DF

# %% [markdown]
# # 1 Normal Slicing
# - both numeric and row_name slicing is possible
# - Only Row wise Slicing is allowed

# %%
syntax-1
            dataframe[start: stop: step]

# %%
syntax-2
datafram[row_name_start:row_name_stop:step]

# %%
bike
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %% [markdown]
# # based on the index number

# %%
bike[1:201:]
# Out:
#      tripduration            starttime             stoptime  start station id  \
# 1            1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2             232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3             190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4             303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5             176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# ..            ...                  ...                  ...               ...
# 196           632  2018-05-01 08:08:19  2018-05-01 08:18:52              3277
# 197           563  2018-05-01 08:08:26  2018-05-01 08:17:50              3199
# 198           218  2018-05-01 08:08:32  2018-05-01 08:12:10              3267
# 199           224  2018-05-01 08:09:21  2018-05-01 08:13:06              3194
# 200           215  2018-05-01 08:10:14  2018-05-01 08:13:49              3209
#
# ...

# %%
bike[1:200:3]

# %%
bike
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
new_bike = bike[0:6:]
new_bike
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
#
#   start station name  end station id end station name   bikeid  \
# 0         Harborside            3199     Newport Pkwy    33558
# 1           Grand St            3185        City Hall    33593
# 2    McGinley Square            3193     Lincoln Park    29217
# 3          City Hall            3186    Grove St PATH    29662
# 4        Oakland Ave            3195          Sip Ave  9999999
# ...

# %%
new_bike.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
["row_"] * 5
# Out:
# ['row_', 'row_', 'row_', 'row_', 'row_']

# %%
idx = ['row_1', 'row_2', 'row_3', 'row_4', 'row_5' , "row_6"]

# %%
new_bike.index = idx

# %%
new_bike
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
# ...

# %%
# using index number

# %%
new_bike[1:4:]  # Stop is Exlusive
# Out:
#        tripduration            starttime             stoptime  \
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
#
#        bikeid                      name_localizedValue    usertype
# row_2   33593                                  24 Hour    Customer
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_4   29662                                  24 Hour    Customer

# %%
# using index we have given

# %%
new_bike["row_2":"row_4":] # Stop is not Exlusive
# Out:
#        tripduration            starttime             stoptime  \
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
#
#        bikeid                      name_localizedValue    usertype
# row_2   33593                                  24 Hour    Customer
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_4   29662                                  24 Hour    Customer

# %%
new_bike

# %%
new_bike[['tripduration' , 'bikeid']]
# Out:
#        tripduration   bikeid
# row_1           338    33558
# row_2          1482    33593
# row_3           232    29217
# row_4           190    29662
# row_5           303  9999999
# row_6           176    29298

# %%
new_bike[0:3 , 0:5 ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(0, 3, None), slice(0, 5, None))
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 new_bike[0:3 , 0:5 ]
#
# ...

# %%
# loc
- does slicing on both rows and columns
- it will do slicing only by the given index

# %%
syntax
dataframe.loc[row_name_start:row_name_stop:row_step ,column_name_start : column_name:stop: column_step ]

# %%
new_bike
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
# ...

# %%
# index numbers

# %%
new_bike.loc[1:5: , 0:4:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 new_bike.loc[1:5: , 0:4:]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_tuple(self, tup)
#    1375 if self._multi_take_opportunity(tup):
#    1376     return self._multi_take(tup)
# -> 1378 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1021, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
# ...

# %%
new_bike.loc["row_2":"row_5": , "tripduration":"start station id": ]
# Out:
#        tripduration            starttime             stoptime  \
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id
# row_2              3681
# row_3              3194
# row_4              3185
# row_5              3207

# %%
bike
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
bike.loc[2:6: , "tripduration":"start station id": ]
# Out:
#    tripduration            starttime             stoptime  start station id
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225

# %%
new_bike
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
# ...

# %%
iloc

# %%
new_bike.iloc["row_2":"row_5": , "tripduration":"start station id": ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 new_bike.iloc["row_2":"row_5": , "tripduration":"start station id": ]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1695, in _iLocIndexer._getitem_tuple(self, tup)
#    1692 with suppress(IndexingError):
#    1693     return self._getitem_lowerdim(tup)
# -> 1695 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
new_bike.iloc[1:5: , "tripduration":"start station id": ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 new_bike.iloc[1:5: , "tripduration":"start station id": ]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1695, in _iLocIndexer._getitem_tuple(self, tup)
#    1692 with suppress(IndexingError):
#    1693     return self._getitem_lowerdim(tup)
# -> 1695 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
new_bike.iloc[1:5: , 0:4: ]
# Out:
#        tripduration            starttime             stoptime  \
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id
# row_2              3681
# row_3              3194
# row_4              3185
# row_5              3207

# %% [markdown]
# # Normal Slicing
# - Only row slicing is allowed
# - can slice based on index numbers or given Indexes
#
# # loc
# - row wise as well as column wise slicing is allowed
# - Only the given index should be used( exception - if index numbers are available those can be used)
#
# # iloc
# - row wise as well as column wise slicing is allowed
# - Only the  index numbers should be used

# %%
new_bike
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# row_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
# ...

# %%
# loc
new_bike.loc["row_3":"row_4",]
# Out:
#        tripduration            starttime             stoptime  \
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
#
#        bikeid                      name_localizedValue    usertype
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_4   29662                                  24 Hour    Customer

# %%
# iloc
new_bike.iloc["row_3":"row_4",]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 2
#       1 # iloc
# ----> 2 new_bike.iloc["row_3":"row_4",]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1695, in _iLocIndexer._getitem_tuple(self, tup)
#    1692 with suppress(IndexingError):
#    1693     return self._getitem_lowerdim(tup)
# -> 1695 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1021, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
# ...

# %%
# iloc
new_bike.iloc[2:4 ]
# Out:
#        tripduration            starttime             stoptime  \
# row_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# row_3              3194    McGinley Square            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
#
#        bikeid                      name_localizedValue    usertype
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_4   29662                                  24 Hour    Customer

# %%
inter_or = pd.read_csv("datasets/international_org.csv")

# %%
inter_or
# Out:
#   Organization Name  Headquater
# 0               FAO        Rome
# 1               ICJ   The Hague
# 2               IMF  Washington
# 3            UNESCO       Paris
# 4               UNO    New York
# 5        World Bank  Washington

# %%
# adding a column

# %%
inter_or["year"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 inter_or["year"]
#
# ...

# %%
inter_or["year"] = 2026

# %%
inter_or
# Out:
#   Organization Name  Headquater  year
# 0               FAO        Rome  2026
# 1               ICJ   The Hague  2026
# 2               IMF  Washington  2026
# 3            UNESCO       Paris  2026
# 4               UNO    New York  2026
# 5        World Bank  Washington  2026

# %%
lst = [2020,2021,2022,2023,2024,2025]

# %%
inter_or["year"] = lst

# %%
inter_or
# Out:
#   Organization Name  Headquater  year
# 0               FAO        Rome  2020
# 1               ICJ   The Hague  2021
# 2               IMF  Washington  2022
# 3            UNESCO       Paris  2023
# 4               UNO    New York  2024
# 5        World Bank  Washington  2025

# %%
rating = pd.read_csv("datasets/imdb_rating.csv")

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
rating.replace("Crime" , "XYZ")
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption        XYZ
# 1          9.2                                  The Godfather        XYZ
# 2          9.1                         The Godfather: Part II        XYZ
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction        XYZ
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
rating.replace("Crime" , "XYZ" , inplace=True)

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption        XYZ
# 1          9.2                                  The Godfather        XYZ
# 2          9.1                         The Godfather: Part II        XYZ
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction        XYZ
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
rating = pd.read_csv("datasets/imdb_rating.csv")

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
rating["genre"].replace("Crime" , "00000" , inplace=True)

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      00000
# 1          9.2                                  The Godfather      00000
# 2          9.1                         The Godfather: Part II      00000
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      00000
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
# Dropping

# %%
rating.drop(columns='duration')
# Out:
#    star_rating                                          title      genre
# 0          9.3                       The Shawshank Redemption      00000
# 1          9.2                                  The Godfather      00000
# 2          9.1                         The Godfather: Part II      00000
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      00000
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      00000
# 1          9.2                                  The Godfather      00000
# 2          9.1                         The Godfather: Part II      00000
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      00000
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
rating.drop(columns='duration' , inplace=True)

# %%
rating
# Out:
#    star_rating                                          title      genre
# 0          9.3                       The Shawshank Redemption      00000
# 1          9.2                                  The Godfather      00000
# 2          9.1                         The Godfather: Part II      00000
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      00000
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama

# %%
rating.drop(columns=["title" , "genre"] , inplace=True)

# %%
rating
# Out:
#    star_rating
# 0          9.3
# 1          9.2
# 2          9.1
# 3          9.0
# 4          8.9
# 5          8.9
# 6          8.9
# 7          8.9
# 8          8.9
# 9          8.9

# %%
rating = pd.read_csv("datasets/imdb_rating.csv")

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
rating.drop(index=1)
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
ne_df = rating.drop(index=[1,2,3,4])

# %%
ne_df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
# Sorting
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
# Ascending order
rating.sort_values(by="star_rating" , ascending=True)
# Out:
#    star_rating                                          title      genre  \
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
# 3          9.0                                The Dark Knight     Action
# 2          9.1                         The Godfather: Part II      Crime
# 1          9.2                                  The Godfather      Crime
# 0          9.3                       The Shawshank Redemption      Crime
#
#    duration
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139
# 3       152
# 2       200
# 1       175
# 0       142

# %%
# Descending order
rating.sort_values(by="star_rating" , ascending=False)
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
# Descending order
rating.sort_values( by=4 , axis=1)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[123], line 2
#       1 # Descending order
# ----> 2 rating.sort_values( by=4 , axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7222, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7219     if isinstance(ascending, (tuple, list)):
#    7220         ascending = ascending[0]
# -> 7222     indexer = nargsort(
#    7223         k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    7224     )
#    7225 else:
#    7226     if inplace:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\sorting.py:439, in nargsort(items, kind, ascending, na_position, key, mask)
#     437     non_nans = non_nans[::-1]
#     438     non_nan_idx = non_nan_idx[::-1]
# --> 439 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     440 if not ascending:
# ...

# %%
# Descending order
rating.sort_values( by="star rating" , axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16020\1296373663.py in ?()
#       1 # Descending order
# ----> 2 rating.sort_values( by="star rating" , axis=1)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7207             )
#    7208         elif len(by):
#    7209             # len(by) == 1
#    7210
# -> 7211             k = self._get_label_or_level_values(by[0], axis=axis)
#    7212
#    7213             # need to rewrap column in Series to apply key function
#    7214             if key is not None:
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
# ...

# %%
# Descending order
rating.sort_index(axis=1)
# Out:
#    duration      genre  star_rating  \
# 0       142      Crime          9.3
# 1       175      Crime          9.2
# 2       200      Crime          9.1
# 3       152     Action          9.0
# 4       154      Crime          8.9
# 5        96      Drama          8.9
# 6       161    Western          8.9
# 7       201  Adventure          8.9
# 8       195  Biography          8.9
# 9       139      Drama          8.9
#
#                                            title
# 0                       The Shawshank Redemption
# 1                                  The Godfather
# 2                         The Godfather: Part II
# 3                                The Dark Knight
# 4                                   Pulp Fiction
# 5                                   12 Angry Men
# 6                 The Good, the Bad and the Ugly
# 7  The Lord of the Rings: The Return of the King
# 8                               Schindler's List
# 9                                     Fight Club

# %%
# Descending order
rating['star_rating'].sort_values( ascending=False)
# Out:
# 0    9.3
# 1    9.2
# 2    9.1
# 3    9.0
# 4    8.9
# 5    8.9
# 6    8.9
# 7    8.9
# 8    8.9
# 9    8.9
# Name: star_rating, dtype: float64

# %%
# Descending order
rating.sort_values(by="star_rating" , ascending=True , inplace=True)

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
# 3          9.0                                The Dark Knight     Action
# 2          9.1                         The Godfather: Part II      Crime
# 1          9.2                                  The Godfather      Crime
# 0          9.3                       The Shawshank Redemption      Crime
#
#    duration
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139
# 3       152
# 2       200
# 1       175
# 0       142

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16020\318991307.py in ?()
# ----> 1 rating.set_index(keys="star rating" , drop=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['star rating'] are in the columns"

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %%
rating.set_index(keys=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 rating.set_index()
#
# TypeError: DataFrame.set_index() missing 1 required positional argument: 'keys'

# %%
rating.reset_index( )
# Out:
#    index  star_rating                                          title  \
# 0      4          8.9                                   Pulp Fiction
# 1      5          8.9                                   12 Angry Men
# 2      6          8.9                 The Good, the Bad and the Ugly
# 3      7          8.9  The Lord of the Rings: The Return of the King
# 4      8          8.9                               Schindler's List
# 5      9          8.9                                     Fight Club
# 6      3          9.0                                The Dark Knight
# 7      2          9.1                         The Godfather: Part II
# 8      1          9.2                                  The Godfather
# 9      0          9.3                       The Shawshank Redemption
#
#        genre  duration
# 0      Crime       154
# 1      Drama        96
# 2    Western       161
# 3  Adventure       201
# 4  Biography       195
# 5      Drama       139
# 6     Action       152
# ...

# %%
rating.reset_index( drop=True)
# Out:
#    star_rating                                          title      genre  \
# 0          8.9                                   Pulp Fiction      Crime
# 1          8.9                                   12 Angry Men      Drama
# 2          8.9                 The Good, the Bad and the Ugly    Western
# 3          8.9  The Lord of the Rings: The Return of the King  Adventure
# 4          8.9                               Schindler's List  Biography
# 5          8.9                                     Fight Club      Drama
# 6          9.0                                The Dark Knight     Action
# 7          9.1                         The Godfather: Part II      Crime
# 8          9.2                                  The Godfather      Crime
# 9          9.3                       The Shawshank Redemption      Crime
#
#    duration
# 0       154
# 1        96
# 2       161
# 3       201
# 4       195
# 5       139
# 6       152
# 7       200
# 8       175
# 9       142

# %%
# Descending order
rating.sort_values(by="title" , ascending=True )
# Out:
#    star_rating                                          title      genre  \
# 5          8.9                                   12 Angry Men      Drama
# 9          8.9                                     Fight Club      Drama
# 4          8.9                                   Pulp Fiction      Crime
# 8          8.9                               Schindler's List  Biography
# 3          9.0                                The Dark Knight     Action
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 0          9.3                       The Shawshank Redemption      Crime
#
#    duration
# 5        96
# 9       139
# 4       154
# 8       195
# 3       152
# 1       175
# 2       200
# 6       161
# 7       201
# 0       142

# %%
rating.at[4 , "star_rating"] = "Tapas"

# %%
rating
# Out:
#   star_rating                                          title      genre  \
# 4       Tapas                                   Pulp Fiction      Crime
# 5         8.9                                   12 Angry Men      Drama
# 6         8.9                 The Good, the Bad and the Ugly    Western
# 7         8.9  The Lord of the Rings: The Return of the King  Adventure
# 8         8.9                               Schindler's List  Biography
# 9         8.9                                     Fight Club      Drama
# 3         9.0                                The Dark Knight     Action
# 2         9.1                         The Godfather: Part II      Crime
# 1         9.2                                  The Godfather      Crime
# 0         9.3                       The Shawshank Redemption      Crime
#
#    duration
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139
# 3       152
# 2       200
# 1       175
# 0       142

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 4 to 0
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   star_rating  10 non-null     object
#  1   title        10 non-null     object
#  2   genre        10 non-null     object
#  3   duration     10 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 700.0+ bytes
