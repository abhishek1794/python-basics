# %% [markdown]
# # Scaling

# %%
Feature Scaling
The process of converting absolute values to comparable values

# %%
1 --> Standard Scaling
2 --> Normalization
3 --> Min Max Scaler

# %%
Normalization
- We use this we do not have the outliers

nor = (x-xmean)/(xmax- xmin)
range(0 to 1)

# %%
Standard Scaling / Standardization
- We use this whe we have outliers
Z = (x-xmean)/(Xstd)
+3 to +3

# %%
Min Max ---> image data
mms = (x-xmin)/(xmax- xmin)
range(0 to 1)

# %%
# Normalization
data = [[-1 , 2],
        [-0.5 , 6],
        [0, 10],
        [1,18]]

# %%
data
# Out:
# [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# %%
from sklearn.preprocessing import normalize

# %%
normalize(data)
# Out:
# array([[-0.4472136 ,  0.89442719],
#        [-0.08304548,  0.99654576],
#        [ 0.        ,  1.        ],
#        [ 0.05547002,  0.99846035]])

# %%
(3-5)/(10-3)
# Out:
# -0.2857142857142857

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()

# %%
data
# Out:
# [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# %%
st.fit_transform(data)
# Out:
# array([[-1.18321596, -1.18321596],
#        [-0.50709255, -0.50709255],
#        [ 0.16903085,  0.16903085],
#        [ 1.52127766,  1.52127766]])

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()

# %%
mms.fit_transform(data)
# Out:
# array([[0.  , 0.  ],
#        [0.25, 0.25],
#        [0.5 , 0.5 ],
#        [1.  , 1.  ]])

# %%
data
# Out:
# [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# %%
Imbalance data
- a data is imbalanced data if below condition is not satisfied

# %%
2 * Minority >= Majority

# %%
yes - 400
no - 300
maybe - 450

# %%
Maj - 450
min ---> 300

# %%
need to balance
Over sampling
Under Sampling

# %%
import pandas as pd
import numpy as np

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import imblearn

# %%
df = pd.read_csv("Case Study Data/creditcard_fraud_data.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4  ...       V26       V27       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155  ... -0.189115  0.133558 -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  0.166480  0.448154  ...  0.125895 -0.008983  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780  ... -0.139097 -0.055353 -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291  ... -0.221929  0.062723  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  1.548718  0.403034  ...  0.502292  0.219422  0.215153   69.99      0
# ...          ...        ...        ...       ...       ...  ...       ...       ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656  ...  0.250034  0.943651  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  ... -0.395255  0.068472 -0.053527   24.79      0
# ...

# %%
df["Class"].unique()
# Out:
# array([0, 1])

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
2*492
# Out:
# 984

# %%
984>=284315
# Out:
# False

# %%
# independent features
x = df.iloc[:: , :-1]

# %%
x
# Out:
#             Time         V1         V2        V3        V4  ...       V25       V26       V27       V28  Amount
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155  ...  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1            0.0   1.191857   0.266151  0.166480  0.448154  ...  0.167170  0.125895 -0.008983  0.014724    2.69
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780  ... -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291  ...  0.647376 -0.221929  0.062723  0.061458  123.50
# 4            2.0  -1.158233   0.877737  1.548718  0.403034  ... -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...        ...        ...       ...       ...  ...       ...       ...       ...       ...     ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656  ...  1.436807  0.250034  0.943651  0.823731    0.77
# ...

# %%
y = df.iloc[:: , -1:]

# %%
y
# Out:
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 1 columns]

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler()

# %%
X_sampled , y_sampled = ros.fit_resample(x ,y)

# %%
X_sampled
# Out:
#            Time         V1         V2         V3        V4  ...       V25       V26       V27       V28  Amount
# 0           0.0  -1.359807  -0.072781   2.536347  1.378155  ...  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1           0.0   1.191857   0.266151   0.166480  0.448154  ...  0.167170  0.125895 -0.008983  0.014724    2.69
# 2           1.0  -1.358354  -1.340163   1.773209  0.379780  ... -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3           1.0  -0.966272  -0.185226   1.792993 -0.863291  ...  0.647376 -0.221929  0.062723  0.061458  123.50
# 4           2.0  -1.158233   0.877737   1.548718  0.403034  ... -0.206010  0.502292  0.219422  0.215153   69.99
# ...         ...        ...        ...        ...       ...  ...       ...       ...       ...       ...     ...
# 568625  51112.0  -9.848776   7.365546 -12.898538  4.273323  ...  0.538665 -0.263934  1.134095  0.225973   99.99
# ...

# %%
y_sampled
# Out:
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 568625      1
# 568626      1
# 568627      1
# 568628      1
# 568629      1
#
# [568630 rows x 1 columns]

# %%
y_sampled.value_counts()
# Out:
# Class
# 0        284315
# 1        284315
# Name: count, dtype: int64

# %% [markdown]
# https://archive.ics.uci.edu/datasets

# %% [markdown]
# https://www.kaggle.com/

# %%
300 CR
GCC

# %%
Random Forest
XG boost

# %%
DE ---> Python, Hadoop , Hive , Sqoop,  Spark, SQL , Streaming , CI CD 
DA ---> SQL , Excel , Power BI/tableau , Mongodb
DS ---> Python , stats , ML , DL , NLP , Gen AI

# %%
Spark
