# %%
# syntax
        file_object = open("path/file_name.ext" , "mode")

# %% [markdown]
# #  different mode of text file

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6CE9-051B
#
#  Directory of C:\Users\Lenovo\Desktop\16 Feb
#
# 17-03-2026  20:46    <DIR>          .
# 17-03-2026  20:46    <DIR>          ..
# 17-03-2026  20:41    <DIR>          .ipynb_checkpoints
# 16-03-2026  21:21    <DIR>          __pycache__
# 03-03-2026  20:12             1,610 Class1_anaconda_installation.ipynb
# 03-03-2026  22:40            40,281 class10_list_comp_exercises.ipynb
# 05-03-2026  22:22            67,066 Class11_tuple_dict.ipynb
# 09-03-2026  22:33           110,932 Class12_dict_methods_set_Conditional_statements.ipynb
# 10-03-2026  22:42            44,586 Class13_loops.ipynb
# 11-03-2026  22:43         4,320,470 Class14_Functions.ipynb
# 12-03-2026  22:36            59,593 Class15_Functions_2.ipynb
# 16-03-2026  22:28           111,056 Class16_function_3_modules_FileHandling.ipynb
# 17-03-2026  20:46             9,835 Class17_File_Handling_2_Excreption_Handling.ipynb
# ...

# %% [markdown]
# # 1 read mode - "r"
# - if file is present/exist then it opens the file in read mode and places the cursor at the begining of the file
# - if file is not present ,then it will throw an error
# - in read mode we can **only** read from the file but we can not write into the file
# - Default mode is read mode

# %%
f = open("my_module.py" , "r")

# %%
f.tell()
# Out:
# 0

# %%
print(f.read())
# Out:
# def Palindrome(str1:str):
#     """
#     This function tells if a string is a palindrome or Not
#     -----------------------------------------
#     Palindrome(string)
#     -----------------------------------------
#     """
#     if str1.lower() == str1.lower()[::-1]:
#         return "Palindrome"
#     else:
#         return "Not a Palindrome"
# def Odd_even(num:int):
#     """
#     This function tells if a number is a Even or Odd
#     -----------------------------------------
#     Odd_even(int)
#     -----------------------------------------
#     """
#     if num%2==0:
#         return "Even"
#     else:
#         return "Odd"

# %%
f.tell()
# Out:
# 602

# %%
# if file is not present
f = open("abcd.txt" , "r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # if file is not present
# ----> 2 f = open("abcd.txt" , "r")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abcd.txt'

# %%
f = open("my_file.txt" , "r")

# %%
# read
print(f.read())
# Out:
# I am writing this text using write function

# %%
f.write("Something i am writing")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 f.write("Something i am writing")
#
# UnsupportedOperation: not writable

# %%
f = open("my_file.txt" , "r")

# %%
f.read()
# Out:
# 'I am writing this text using write function'

# %% [markdown]
# # 2 write mode - "w"
# - if file is present then it opens the file in write mode and it will erase all the previous data in the file
# - if file is not present ,then it will create a new file wih the given name and extension
# - in write mode we are allowed to write into the file, but we are not allowed to read from the file

# %%
# file is present
f = open("my_file.txt" , "w")

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6CE9-051B
#
#  Directory of C:\Users\Lenovo\Desktop\16 Feb
#
# 17-03-2026  21:06    <DIR>          .
# 17-03-2026  21:06    <DIR>          ..
# 17-03-2026  20:41    <DIR>          .ipynb_checkpoints
# 16-03-2026  21:21    <DIR>          __pycache__
# 03-03-2026  20:12             1,610 Class1_anaconda_installation.ipynb
# 03-03-2026  22:40            40,281 class10_list_comp_exercises.ipynb
# 05-03-2026  22:22            67,066 Class11_tuple_dict.ipynb
# 09-03-2026  22:33           110,932 Class12_dict_methods_set_Conditional_statements.ipynb
# 10-03-2026  22:42            44,586 Class13_loops.ipynb
# 11-03-2026  22:43         4,320,470 Class14_Functions.ipynb
# 12-03-2026  22:36            59,593 Class15_Functions_2.ipynb
# 16-03-2026  22:28           111,056 Class16_function_3_modules_FileHandling.ipynb
# 17-03-2026  21:06            18,104 Class17_File_Handling_2_Excreption_Handling.ipynb
# ...

# %%
# if file is not present
f = open("abc.txt" , "w")

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6CE9-051B
#
#  Directory of C:\Users\Lenovo\Desktop\16 Feb
#
# 17-03-2026  21:07    <DIR>          .
# 17-03-2026  21:07    <DIR>          ..
# 17-03-2026  20:41    <DIR>          .ipynb_checkpoints
# 16-03-2026  21:21    <DIR>          __pycache__
# 17-03-2026  21:07                 0 abc.txt
# 03-03-2026  20:12             1,610 Class1_anaconda_installation.ipynb
# 03-03-2026  22:40            40,281 class10_list_comp_exercises.ipynb
# 05-03-2026  22:22            67,066 Class11_tuple_dict.ipynb
# 09-03-2026  22:33           110,932 Class12_dict_methods_set_Conditional_statements.ipynb
# 10-03-2026  22:42            44,586 Class13_loops.ipynb
# 11-03-2026  22:43         4,320,470 Class14_Functions.ipynb
# 12-03-2026  22:36            59,593 Class15_Functions_2.ipynb
# 16-03-2026  22:28           111,056 Class16_function_3_modules_FileHandling.ipynb
# ...

# %%
# read
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[18], line 2
#       1 # read
# ----> 2 f.read()
#
# UnsupportedOperation: not readable

# %%
# write
f.write("Alpha charlie")
# Out:
# 13

# %%
f.close()

# %%
f = open("abc.txt" , "w")

# %%
f.write("Beta Gamma")
# Out:
# 10

# %%
f.close()

# %% [markdown]
# # 3 append mode - "a"
# - if file is present then it opens the file in append mode and it will place the cursor end of the file
# - if file is not present ,then it will create a new file wih the given name and extension
# - in append mode we are allowed to write into the file but we are not allwed to read from the file
# - seek() - it will no be applicable

# %%
# if file is present
f = open("abc.txt" , "a")

# %%
print(f.tell())
# Out:
# 10

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6CE9-051B
#
#  Directory of C:\Users\Lenovo\Desktop\16 Feb
#
# 17-03-2026  21:18    <DIR>          .
# 17-03-2026  21:18    <DIR>          ..
# 17-03-2026  21:08    <DIR>          .ipynb_checkpoints
# 16-03-2026  21:21    <DIR>          __pycache__
# 17-03-2026  21:11                10 abc.txt
# 03-03-2026  20:12             1,610 Class1_anaconda_installation.ipynb
# 03-03-2026  22:40            40,281 class10_list_comp_exercises.ipynb
# 05-03-2026  22:22            67,066 Class11_tuple_dict.ipynb
# 09-03-2026  22:33           110,932 Class12_dict_methods_set_Conditional_statements.ipynb
# 10-03-2026  22:42            44,586 Class13_loops.ipynb
# 11-03-2026  22:43         4,320,470 Class14_Functions.ipynb
# 12-03-2026  22:36            59,593 Class15_Functions_2.ipynb
# 16-03-2026  22:28           111,056 Class16_function_3_modules_FileHandling.ipynb
# ...

# %%
# if file is not present ,
f = open("xyz.txt" , "a")

# %% [markdown]
# # seek()

# %%
pwd
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\16 Feb'

# %%
f = open(r"C:\Users\Lenovo\Desktop\16 Feb\abc.txt" , "r")

# %%
f.tell()
# Out:
# 0

# %%
f.read()
# Out:
# 'Beta Gamma'

# %%
f.tell()
# Out:
# 10

# %%
f.seek(5)
# Out:
# 5

# %%
f.tell()
# Out:
# 5

# %%
f.read()
# Out:
# 'Gamma'

# %%
f.read()
# Out:
# ''

# %%
f.tell()
# Out:
# 10

# %%
f.seek(12)
# Out:
# 12

# %%
f.tell()
# Out:
# 12

# %%
f = open("abc.txt" , "a")

# %%
f.tell()
# Out:
# 10

# %%
f.write("I am writing in append Mode")
# Out:
# 27

# %%
f.close()

# %%
f = open("abc.txt" , "a")

# %%
f.tell()
# Out:
# 37

# %%
f.seek(0)
# Out:
# 0

# %%
f.tell()
# Out:
# 0

# %%
f.write("SOMETHING")
f.close()

# %%
s = "Football is a sport"

# %%
s[9]
# Out:
# 'i'

# %%
tell()-----> only used in File handling

# %% [markdown]
# # 4  read and write - "r+"
# - if file is exist then it opens the file in read mode and places the cursor at the begining of the file
# - if file is not present ,then it will throw an error
# - we are allowed to read from the file as wel as write into the file
# - Note - the data will be overridden

# %%
f = open("abc.txt" , "r+")

# %%
f.tell()
# Out:
# 0

# %%
f.read()
# Out:
# 'Beta GammaI am writing in append ModeSOMETHING'

# %%
# file not present
f = open("hello.txt" , "r+")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[59], line 2
#       1 # file not present
# ----> 2 f = open("hello.txt" , "r+")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hello.txt'

# %%
f = open("abc.txt" , "r+")

# %%
f.write("I am writing in r+ MODE")
f.close()

# %%
f = open("abc.txt" , "r+")
f.write("1234567890")
f.close()

# %%
f = open("abc.txt" , "r+")

# %%
f.tell()
# Out:
# 0

# %%
f.read()
# Out:
# '1234567890 clean and i can build an algorithm'

# %%
f.tell()
# Out:
# 45

# %%
f.write("MY NEW TEXT")
f.close()

# %% [markdown]
# # 5  write and read- "w+"
#  - if file is present then it opens the file in write mode and it will erase all the previous data in the file
#  - if file is not present ,then it will create a new file wih the given name and extension
#  - in w+ mode we are allowed to write into the file, as well as read from the file

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6CE9-051B
#
#  Directory of C:\Users\Lenovo\Desktop\16 Feb
#
# 17-03-2026  21:58    <DIR>          .
# 17-03-2026  21:58    <DIR>          ..
# 17-03-2026  21:08    <DIR>          .ipynb_checkpoints
# 16-03-2026  21:21    <DIR>          __pycache__
# 17-03-2026  21:54                56 abc.txt
# 03-03-2026  20:12             1,610 Class1_anaconda_installation.ipynb
# 03-03-2026  22:40            40,281 class10_list_comp_exercises.ipynb
# 05-03-2026  22:22            67,066 Class11_tuple_dict.ipynb
# 09-03-2026  22:33           110,932 Class12_dict_methods_set_Conditional_statements.ipynb
# 10-03-2026  22:42            44,586 Class13_loops.ipynb
# 11-03-2026  22:43         4,320,470 Class14_Functions.ipynb
# 12-03-2026  22:36            59,593 Class15_Functions_2.ipynb
# 16-03-2026  22:28           111,056 Class16_function_3_modules_FileHandling.ipynb
# ...

# %%
f = open("xyz.txt" , "w+")

# %%
f.tell()
# Out:
# 0

# %%
f.write("This i the new text i am writing into the file")
# Out:
# 46

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'This i the new text i am writing into the file'

# %% [markdown]
# # 6 append and read- "a+"
# - if file is present then it opens the file in append mode and it will place the cursor end of the file
# - if file is not present ,then it will create a new file wih the given name and extension
# - in append and read mode we are allowed to write into the file as well as read from the file
# - seek() - it will no be applicable

# %%
f = open('abc.txt' , "a+")

# %%
f.tell()
# Out:
# 56

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.tell()
# Out:
# 0

# %%
f.read()
# Out:
# '1234567890 clean and i can build an algorithmMY NEW TEXT'

# %%
CRUD

# %%
append()

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6CE9-051B
#
#  Directory of C:\Users\Lenovo\Desktop\16 Feb
#
# 17-03-2026  22:12    <DIR>          .
# 17-03-2026  22:12    <DIR>          ..
# 17-03-2026  22:01    <DIR>          .ipynb_checkpoints
# 16-03-2026  21:21    <DIR>          __pycache__
# 17-03-2026  21:54                56 abc.txt
# 03-03-2026  20:12             1,610 Class1_anaconda_installation.ipynb
# 03-03-2026  22:40            40,281 class10_list_comp_exercises.ipynb
# 05-03-2026  22:22            67,066 Class11_tuple_dict.ipynb
# 09-03-2026  22:33           110,932 Class12_dict_methods_set_Conditional_statements.ipynb
# 10-03-2026  22:42            44,586 Class13_loops.ipynb
# 11-03-2026  22:43         4,320,470 Class14_Functions.ipynb
# 12-03-2026  22:36            59,593 Class15_Functions_2.ipynb
# 16-03-2026  22:28           111,056 Class16_function_3_modules_FileHandling.ipynb
# ...

# %%
rm xyz.txt
# Out:
#   Cell In[82], line 1
#     rm xyz.txt
#        ^
# SyntaxError: invalid syntax

# %%
rm rf xyz.txt
# Out:
#   Cell In[83], line 1
#     rm rf xyz.txt
#        ^
# SyntaxError: invalid syntax

# %%
import sys
import os

# %%
print(dir(os))
# Out:
# ['DirEntry', 'EX_OK', 'F_OK', 'GenericAlias', 'Mapping', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_walk_symlinks_as_files', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath',
# ...

# %%
os.remove

# %%
print(dir(sys))
# Out:
# ['__breakpointhook__', '__displayhook__', '__doc__', '__excepthook__', '__interactivehook__', '__loader__', '__name__', '__package__', '__spec__', '__stderr__', '__stdin__', '__stdout__', '__unraisablehook__', '_base_executable', '_clear_type_cache', '_current_exceptions', '_current_frames', '_debugmallocstats', '_enablelegacywindowsfsencoding', '_framework', '_getframe', '_getframemodulename', '_git', '_home', '_setprofileallthreads', '_settraceallthreads', '_stdlib_dir', '_vpath', '_xoptions', 'activate_stack_trampoline', 'addaudithook', 'api_version', 'argv', 'audit', 'base_exec_prefix', 'base_prefix', 'breakpointhook', 'builtin_module_names', 'byteorder', 'call_tracing', 'copyright', 'deactivate_stack_trampoline', 'displayhook', 'dllhandle', 'dont_write_bytecode', 'exc_info', 'excepthook', 'exception', 'exec_prefix', 'executable', 'exit', 'flags', 'float_info', 'float_repr_style', 'get_asyncgen_hooks', 'get_coroutine_origin_tracking_depth', 'get_int_max_str_digits', 'getallocated
# ...

# %%
os.remove("xyz.txt")

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6CE9-051B
#
#  Directory of C:\Users\Lenovo\Desktop\16 Feb
#
# 17-03-2026  22:16    <DIR>          .
# 17-03-2026  22:16    <DIR>          ..
# 17-03-2026  22:01    <DIR>          .ipynb_checkpoints
# 16-03-2026  21:21    <DIR>          __pycache__
# 17-03-2026  21:54                56 abc.txt
# 03-03-2026  20:12             1,610 Class1_anaconda_installation.ipynb
# 03-03-2026  22:40            40,281 class10_list_comp_exercises.ipynb
# 05-03-2026  22:22            67,066 Class11_tuple_dict.ipynb
# 09-03-2026  22:33           110,932 Class12_dict_methods_set_Conditional_statements.ipynb
# 10-03-2026  22:42            44,586 Class13_loops.ipynb
# 11-03-2026  22:43         4,320,470 Class14_Functions.ipynb
# 12-03-2026  22:36            59,593 Class15_Functions_2.ipynb
# 16-03-2026  22:28           111,056 Class16_function_3_modules_FileHandling.ipynb
# ...

# %% [markdown]
# # with open

# %%
open()
f.write()
f.close()

# %%
syntax
with open("file_path/file_name.ext" ,"mode") as file_obj:
    f.w
    .
    .
    .
    code

# %%
with open("abc.txt" , "r") as f:
    print(f.tell())
    print(f.read())
# Out:
# 0
# 1234567890 clean and i can build an algorithmMY NEW TEXT

# %%
# functions
read()
readline()
readlines()

write()
writelines()

# %%
with open("abc.txt" , "r") as f:
    var = f.read()

# %%
var
# Out:
# 'We are learning File Handling\nWe are enjoying it\nPython is a godd programming language\nwe have learnt coding'

# %%
len(var)
# Out:
# 108

# %%
with open("abc.txt" , "r") as f:
    print(f.readline())
    print(f.tell())
    f.seek(30)
    print(f.readline())
# Out:
# We are learning File Handling
#
# 30
# We are enjoying it

# %%
with open("abc.txt" , "r") as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['We are learning File Handling\n',
#  'We are enjoying it\n',
#  'Python is a godd programming language\n',
#  'we have learnt coding']

# %%
with open("abc.txt" , "r") as f:
    sentence = f.read()

# %%
words = sentence.split()

# %%
print(words)
# Out:
# ['We', 'are', 'learning', 'File', 'Handling', 'We', 'are', 'enjoying', 'it', 'Python', 'is', 'a', 'godd', 'programming', 'language', 'we', 'have', 'learnt', 'coding']

# %%
words[0] = "I"

# %%
words
# Out:
# ['I',
#  'are',
#  'learning',
#  'File',
#  'Handling',
#  'We',
#  'are',
#  'enjoying',
#  'it',
#  'Python',
#  'is',
#  'a',
#  'godd',
#  'programming',
#  'language',
#  'we',
#  'have',
#  'learnt',
#  'coding']

# %%
new_sentence = " ".join(words)

# %%
f = open("abc.txt" , "w")

# %%
f.write(new_sentence)
# Out:
# 107

# %%
writelins ---> it will take a list and writes into the file

# %%
with open("abc.txt" , "w+") as f:
    f.writelines(words)

# %%
with open("abc.txt" , "r") as f:
    sentence = f.readline()

# %%
sentence
# Out:
# 'IarelearningFileHandlingWeareenjoyingitPythonisagoddprogramminglanguagewehavelearntcoding'

# %%
f.close()
