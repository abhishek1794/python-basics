# %% [markdown]
# # Matplotlib

# %%
- Python library to Visualize data

# %%
image ---> data

# %%
# install

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
week_day=[1,2,3,4,5,6,7]
temp=[50,51,52,48,47,49,46]

# %%
plt.plot(week_day ,temp )
plt.show()

# %%
plt.plot(week_day ,temp )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.show()

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
plt.plot(week_day ,temp , color='g' )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.show()

# %%
plt.plot(week_day ,temp , color='m' )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.show()

# %%
# color
plt.plot(week_day ,temp , color='c' )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.show()

# %%
# line style
plt.plot(week_day ,temp , color='r' , linestyle="-" )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.show()

# %%
# line style
plt.plot(week_day ,temp , color='r' , linestyle="--" )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.show()

# %%
# line style
plt.plot(week_day ,temp , color='r' , linestyle="-." )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.show()

# %%
# Markers

plt.plot(week_day ,temp , color='b' , linestyle="-",marker="o" )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.show()

# %%
# Markers

plt.plot(week_day ,temp , color='b' , linestyle="-",marker=">" )
plt.xlabel("Day")
plt.ylabel("Temp")
# plt.grid()
plt.show()

# %%
# title

plt.plot(week_day ,temp , color='b' , linestyle="-",marker=">" )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.title("Day vs temp")
# plt.grid()
plt.show()

# %%
# format string in Matplotlib
syntax

fmt = '[marker][line][color]'

# %%
">--b"

# %%
plt.plot(week_day ,temp , color='b' , linestyle="-",marker=">" )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.title("Day vs temp")
# plt.grid()
plt.show()

# %%
plt.plot(week_day ,temp , ">--b" )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.title("Day vs temp")
# plt.grid()
plt.show()

# %%
plt.plot(week_day ,temp , "--b>" )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.title("Day vs temp")
# plt.grid()
plt.show()

# %%
days=[1,2,3,4,5,6,7] 
max_t=[50,51,52,48,47,49,46] 
min_t=[43,42,40,44,45,35,37] 
avg_t=[45,48,48,46,40,42,41]

# %%
plt.plot(week_day,max_t  )
plt.plot(week_day, min_t )
plt.plot(week_day, avg_t )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.title("Day vs temp")
# plt.grid()
plt.show()

# %%
legend()

# %%
plt.plot(week_day,max_t  )
plt.plot(week_day, min_t )
plt.plot(week_day, avg_t )
plt.xlabel("Day")
plt.ylabel("Temp")
plt.title("Day vs temp")
# plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10048\2262797348.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# labels
plt.plot(week_day,max_t , color='b' , linestyle="-",marker=">", label="Max" ,  )
plt.plot(week_day, min_t, label="Min" )
plt.plot(week_day, avg_t , label="Avg")
plt.xlabel("X - Day")
plt.ylabel("Y - Temp")
plt.title("Day vs temp")
plt.grid()
plt.legend()
plt.show()

# %%
# labels
plt.plot(week_day,max_t , color='b' , linestyle="-",marker=">", label="Max" ,  )
plt.plot(week_day, min_t, label="Min" )
plt.plot(week_day, avg_t , label="Avg")
plt.xlabel("X - Day")
plt.ylabel("Y - Temp")
plt.title("Day vs temp")
plt.grid()
plt.legend(loc = "lower left")
plt.show()

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
# Bar plot
plt.bar(company , revenue)
plt.show()

# %%
plt.barh(company , revenue)
plt.show()

# %%
blood_sugar = [113,85,90,150,149,88,93,115,135,80,77,82,129]

# %%
Normal --> 80 - 100
Pre Diabitic ---> 100 - 120
Diabitic ----> 120 <

# %%
Histogram

# %%
plt.hist(blood_sugar)
plt.show()

# %%
bin = 10

# %%
blood_sugar = [113,85,90,150,149,88,93,115,135,80,77,82,129]

# %%
Normal --> 77 - 100
Pre Diabitic ---> 100 - 125
Diabitic ----> 125  - 150

# %%
Normal --> min(list) - 100
Pre Diabitic ---> 100 - 125
Diabitic ----> 125  - max(list)

# %%
min(blood_sugar)
# Out:
# 77

# %%
plt.hist(blood_sugar, bins=[min(blood_sugar) , 100,125,max(blood_sugar)])
plt.show()

# %%
Normal --> 7
Pre Diabitic ---> 2
Diabitic ----> 4

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

# %%
pie plot

# %%
plt.pie(exp_vals)
plt.show()

# %%
plt.pie(exp_vals , labels=exp_labels)
plt.show()

# %%
plt.pie(exp_vals , labels=exp_labels, autopct="%0.0f%%")
plt.show()

# %%
plt.pie(exp_vals , labels=exp_labels, autopct="%0.2f%%")
plt.show()

# %%
plt.pie(exp_vals , labels=exp_labels, autopct="%0.2f%%" , radius=1.5)
plt.show()

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]
[0,0,0,0,0.5]

# %%
plt.pie(exp_vals , labels=exp_labels, autopct="%0.2f%%", explode=[0,0,0,0,0.5])
plt.show()

# %%
x, y

# %%
x = [1,2,3,4,5,6,7,8]
y = [5,2,5,7,8,4,2,5]

# %%
plt.scatter(x, y)

# %%
year=[2014,2015,2016,2017]
income=[4000,4500,5300,4600]

expense=[2800,3000,2800,3400]

# %%
# Sub plots

# %%
plt.subplot(2 ,1, 1)
plt.bar(year , income)

plt.subplot(2 ,1, 2)
plt.bar(year , expense)
# Out:
# <BarContainer object of 4 artists>

# %%
(row , column , location)

# %%
(2 ,1, 1)

# %%
plt.subplot(2 ,2, 1)
plt.bar(year , income)

plt.subplot(2 ,2, 2)
plt.bar(year , expense)

plt.subplot(2 ,2, 3)
plt.scatter(x, y)

plt.subplot(2 ,2, 4)
plt.plot(year , expense)

# %%
(row , column , location)

# %% [markdown]
# # Seaborn

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
pd.read_csv("datasets/tips.csv")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips["time"].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = "total_bill", y = "tip", data=tips )
plt.show()

# %%
3 data is linear
there are outliers
maximum data lies b/w 10 to 30

# %%
sns.relplot(x = "total_bill", y = "tip", data=tips  , hue="smoker")
plt.show()

# %%
sns.relplot(x = "total_bill", y = "tip", data=tips  , hue="smoker", style="time")
plt.show()

# %%
sns.relplot(x = "total_bill", y = "tip", data=tips )
plt.show()

# %%
tips["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.relplot(x = "total_bill", y = "tip", size="size",data=tips )
plt.show()

# %%
sns.relplot(x = "total_bill", y = "tip", data=tips  , hue="smoker",  size="time",style="size")
plt.show()

# %%
50$
10$ tip
smoker
3 people
dinner

# %%
sns.relplot(x = "total_bill", y = "tip", data=tips  , hue="smoker",  size="time",style="size" , col="time")
plt.show()

# %%
"iris"

# %%
iris = pd.read_csv("datasets/iris.csv")

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.scatterplot(x = "sepal_length" , y="petal_length" , data=iris , hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
# box plot
# - to plot outliers

# %%
sns.boxplot(x = "total_bill" , data=tips)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(y = "total_bill" , data=tips)
# Out:
# <Axes: ylabel='total_bill'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x= "day" , y="total_bill" , data=tips)

# %%
weekend more customers---> increase the work force
Friday ---> less cust ----> give offers to attaract customers

# %%
sns.catplot(x= "day" , y="total_bill" , data=tips, kind = "box")

# %%
sns.catplot(x= "day" , y="total_bill" , data=tips, kind = "swarm")

# %%
sns.catplot(x= "day" , y="total_bill" , data=tips, kind = "violin")

# %%
# normal plot 
# distribution

# %%
x = np.random.randn(100)

# %%
x
# Out:
# array([-0.6637767 , -0.56991819,  0.61291244, -0.3740401 , -0.65622564,
#         0.24346512,  0.14323389, -0.53139754, -0.10260461,  0.44963517,
#         1.25922295,  0.53195231,  0.15442848,  1.47308282,  1.13590778,
#        -0.30320205,  1.28960807, -0.7012658 , -0.6078445 ,  1.17459415,
#         0.69940908,  1.04357629, -0.39358142, -2.14439607, -0.46281999,
#        -1.87223494, -0.9444783 ,  0.03272272,  0.59846441, -1.0266542 ,
#        -1.81356361,  1.7339544 , -0.02341505, -1.19517331, -1.30257193,
#         0.09101234, -0.51732942,  2.05562671, -0.64219406,  2.24186954,
#         0.21271164,  1.81252404, -0.19707316,  0.23533967, -0.18480639,
#        -1.02414267, -0.35171764,  1.46428528,  1.51259254, -1.28017812,
#        -1.34770522,  0.97261755,  1.40289523, -0.01049154, -0.49946761,
#        -0.98231563, -0.52895333, -0.78823841,  0.2535815 ,  0.45949848,
#        -0.42265284,  2.32219577, -0.04169879,  2.08038799, -1.20598356,
# ...

# %%
sns.distplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x , kde=False)
# Out:
# <Axes: >

# %%
joint plot

# %%
sns.jointplot(x = "total_bill" , y="tip" , data=tips)

# %%
Skewness

# %%
pairplot

# %%
heatmap

# %%
sns.pairplot(iris)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
numeric_data = iris[["sepal_length" ,"sepal_width" , "petal_length" , "petal_width" ]]

# %%
sns.heatmap(iris)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 sns.heatmap(iris)
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)    443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# ...

# %%
val = numeric_data.corr()

# %%
val
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap( val)
# Out:
# <Axes: >
