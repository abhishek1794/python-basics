# %% [markdown]
# # Python Components

# %%
a = 10

# %% [markdown]
# - Literals
# - Identifiers
# - Constants
# - Reserved Words/Keywords
# - Statements and Expressions
# - Block and Indentation
# - Comments

# %% [markdown]
# # Literals
# - Any value you see in python is called as literal

# %%
int
float
complex
str
list
set

# %%
b = "Jarvis"
c = 99
d = 0.0000034455
n = 2+4J

# %%
print(10)

# %% [markdown]
# # Constants
# - Values that do not change

# %%
pie = 3.146

# %%
PI = 3.14

# %%
PI
# Out:
# 3.14

# %%
PI = 500 # this is a constant value do not change it

# %%
PI
# Out:
# 500

# %%
# Standards ---> use UPPER case for constants

# %%
GRAVITY = 9.81 # constant value

# %%
CONST ="JHON"

# %% [markdown]
# # Identifiers/variables
# - name given to the literal

# %%
d = 0.0000034455

# %%
var = 9876

# %%
var
# Out:
# 9876

# %% [markdown]
# # NOTE - Python is a **Case Sensitive** Language

# %%
Rules to declare an identifier
- Allowed char are A-Z , a-z , 0-9 , _
- Can not start with numbers
- can not have special char but can use _
- Identifiers are case sensitive
- no space b/w
- Resvered words should not be used as a Identifier

# %%
ABC = 7000

# %%
ABC
# Out:
# 7000

# %%
xyz = 8888

# %%
xyz
# Out:
# 8888

# %%
Abc = 555

# %%
Abc
# Out:
# 555

# %%
ABC_xyz_1 = 555.90909

# %%
ABC_xyz_1
# Out:
# 555.90909

# %%
ABC = 555

# %%
abc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 abc
#
# NameError: name 'abc' is not defined

# %%
print

# %%
PRINT

# %%
1var = 99000
# Out:
#   Cell In[20], line 1
#     1var = 99000
#     ^
# SyntaxError: invalid decimal literal

# %%
var1 = 99000

# %%
# special char

# %%
$var = 7654
# Out:
#   Cell In[22], line 1
#     $var = 7654
#     ^
# SyntaxError: invalid syntax

# %%
var% = 8
# Out:
#   Cell In[23], line 1
#     var% = 8
#          ^
# SyntaxError: invalid syntax

# %%
var() = 6764
# Out:
#   Cell In[24], line 1
#     var() = 6764
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
_var = 345

# %%
*var = 99
# Out:
#   Cell In[27], line 1
#     *var = 99
#     ^
# SyntaxError: starred assignment target must be in a list or tuple

# %%
var_1 = "Jemma"

# %%
var_1
# Out:
# 'Jemma'

# %%
lmn = 0

# %%
LMN = 99

# %%
lmn
# Out:
# 0

# %%
LMN
# Out:
# 99

# %%
var 1 = "something"
# Out:
#   Cell In[35], line 1
#     var 1 = "something"
#         ^
# SyntaxError: invalid syntax

# %%
var_1 = "something"

# %%
 a,b=11
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 a,b=11
#
# TypeError: cannot unpack non-iterable int object

# %%
$$$$ = 9999
# Out:
#   Cell In[40], line 1
#     $$$$ = 9999
#     ^
# SyntaxError: invalid syntax

# %%
_ = 7000

# %%
_
# Out:
# 7000

# %%
lmn
# Out:
# 0

# %%
del lmn

# %%
lmn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 lmn
#
# NameError: name 'lmn' is not defined

# %%
# = 66

# %% [markdown]
# # Reserved Words/Keywords
# - Reserved Words are the words in python which have a meaning/function already

# %%
example = print , import , sum , if , else , while .....

# %%
print("Iron Man")
# Out:
# Iron Man

# %%
print = 30

# %%
print("Iron Man")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print("Iron Man")
#
# TypeError: 'int' object is not callable

# %%
30("Iron Man")
# Out:
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17776\2693104881.py:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   30("Iron Man")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 30("Iron Man")
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
print("Iron Man")
# Out:
# Iron Man

# %%
import keyword

# %%
print(dir(keyword))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'iskeyword', 'issoftkeyword', 'kwlist', 'softkwlist']

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
print(len(dir(__builtins__)))
# Out:
# 161

# %% [markdown]
# # Statements and Expressions

# %%
a = 200 # Statement

# %%
e = 5520 + 290 -330 # Expression

# %% [markdown]
# # Block and Indentation

# %%
block-----> few lines of code

# %%
line 1 
line 2 
line 3
line 4
line 5
line 6

# %%
Indentation - spaces after a function , loop , conditional statemt, class

# %%
a = 10
b = 20
c = 30

# %%
a = 10
if a == 10:
 print("10")
 print("Iron man")
 print("Hulk")
 print("Thor")
b = 2000
# Out:
# 10
# Iron man
# Hulk
# Thor

# %%
if(condition)
{
code
code
code
}

# %%
a=10
if a==10:
    print("10")
    print("Iron man")
    print("Hulk")
    print("Thor")
b = 2000
# Out:
# 10
# Iron man
# Hulk
# Thor

# %%
a=10
if a==10:
 print("hi")
 b=7
print(b)

# %% [markdown]
#  # Comments - (#)

# %%
1 - for Documentation (code explaination)
2 -

# %%
var1 = 10
#var2 = 20
print(var1)
# Out:
# 10

# %%
var2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 var2
#
# NameError: name 'var2' is not defined

# %%
# var1
# var2
# var3
# var4

# %%
# Multiline comment

# %%
'''
This is 
a Multi line 
comment
'''
a = 200
a
# Out:
# 200

# %%
if a==10:
    '''
    This is 
    a Multi line 
    comment
    '''
    print("10")
    print("Iron man")
    print("Hulk")
    print("Thor")

# %%
''' 
ab=10
bc=20
ab-bc
'''
# Out:
# ' \nab=10\nbc=20\nab-bc\n'

# %%
# This is not working

a= 10

# comment

b = 50

'''
This is 
multi line
comment 
section
'''
a
# Out:
# 10

# %%
l = [1,2,3,4,5]
for i in l:
    print("10")
    print("Iron man")
    print("Hulk")
    print("Thor")
# Out:
# 10
# Iron man
# Hulk
# Thor
# 10
# Iron man
# Hulk
# Thor
# 10
# Iron man
# Hulk
# Thor
# 10
# Iron man
# Hulk
# Thor
# 10
# Iron man
# Hulk
# Thor

# %% [markdown]
# # Data Types in Python
# - 1 - Fundamenta data type / Primitive Data type
#     - int
#     - float
#     - bool
#     - str
#     - complex
#     - None
#
#
# - 2 - Derived data type
#     - list
#     - tuple
#     - dict
#     - set
#     - frozenset

# %% [markdown]
# # Integer(int) Whole numbers
# - Any number without decimal point is an Integer

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
b = 0
type(b)
# Out:
# int

# %%
c = -999
c
# Out:
# -999

# %%
type(c)
# Out:
# int

# %%
print(type(c))
# Out:
# <class 'int'>

# %%
# Arithmetic Operations
+ ----> addition
- ----> Subtraction
* ----> Multiplication
/ ----> Float division 
// ----> Floor Division
% ---> Modulus
** ----> Power/exponent

# %%
a = 95
b = 55

# %%
# addition
a+b
# Out:
# 150

# %%
# subtraction
a - b
# Out:
# 40

# %%
# Multiplication
a * b
# Out:
# 5225

# %%
10/5
# Out:
# 2.0

# %%
14/3
# Out:
# 4.666666666666667

# %%
# Floor division

# %%
floor and Ceiling
4.666666666666667

# %%
4 (floor)<-------------- 4.666666666666667-------> 5(ceil)

# %%
import math
math.ceil(4.666666666666667)
# Out:
# 5

# %%
14//-3
# Out:
# -5

# %%
math.ceil(14/3)
# Out:
# 5

# %%
3)14(4 -----> quotient(division)

  12    
-----
   2 -----> Remainder

# %%
Modulus ---> Remainder

# %%
14%3
# Out:
# 2

# %%
10%5
# Out:
# 0

# %%
Power

# %%
(2)**4
# Out:
# 16
