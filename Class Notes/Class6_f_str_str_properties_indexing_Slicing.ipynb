# %%
WAP
- take 2 numbers as input from the user and get the sum of those two numbers

# %%
"first number is input1, second number is input2 and sum of these two numbers is num1+num2"

# %%
num1 = 80

# %%
"first number is 10, second number is 20 and sum of these two numbers is 30"
# Out:
# 'first number is 10, second number is 20 and sum of these two numbers is 30'

# %%
num1 = int(input("Please enter first number: "))
num2 = int(input("Please enter second number: "))
total = num1 + num2
total
# Out:
# Please enter first number:  55
# Please enter second number:  990
# 1045

# %%
print("first number is ",num1, "second number is ",num2, " and sum of these two numbers is ",total)
# Out:
# first number is  55 second number is  990  and sum of these two numbers is  1045

# %%
# format string
# - it is a way of writing string in dynamic fashion

# %%
1 --> f""
2---> .format()

# %%
num1 = int(input("Please enter first number: "))
num2 = int(input("Please enter second number: "))
print(f"first number is {num1}, second number is {num2} and sum of these two numbers is {num1+num2}")
# Out:
# Please enter first number:  5000
# Please enter second number:  654
# first number is 5000, second number is 654 and sum of these two numbers is 5654

# %%
first_name= input("Please enter first name: ")
last_name = input("Please enter last name: ")
# Out:
# Please enter first name:  mohammed
# Please enter last name:  Usman

# %%
print(f"first name is {first_name}, last name is {last_name} and sum of these two numbers is {num1+num2}")
# Out:
# first name is mohammed, last name is Usman

# %%
first_name= input("Please enter first name: ")
last_name = input("Please enter last name: ")
print("first name is {} , last name is {} ".format(first_name ,last_name ))
# Out:
# Please enter first name:  Mark
# Please enter last name:  Zukerberg
# first name is Mark , last name is Zukerberg

# %%
print("first number is {}, second number is {} and sum of these two numbers is {}".format(num1 ,num2,(num1+num2) ))
# Out:
# first number is 5000, second number is 654 and sum of these two numbers is 5654

# %%
print(f"first number is {num1},second number is {num2} and sum of these two number is {num1 + num2}" )
# Out:
# first number is 5000,second number is 654 and sum of these two number is 5654

# %%
print("first number is", num1, "second number is" ,num2, "and sum of these two numbers is",total)
# Out:
# first number is 5000 second number is 654 and sum of these two numbers is 1045

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
#String Properties
-

# %%
name = input("Please enter your name: ")
print(f"Welcome {name} , to XYZ bank")
# Out:
# Please enter your name:  Saumya
# Welcome Saumya , to XYZ bank

# %%
num1 = int(input("Please enter first number: "))
num2 = int(input("Please enter second number: "))

print(f"first number is {num1}, second number is {num2} and sum of these two numbers is {num1+num2}")
# Out:
# Please enter first number:  1
# Please enter second number:  2
# first number is 1, second number is 2 and sum of these two numbers is 3

# %%
num1 = float(input("Please enter first number: "))
num2 = float(input("Please enter second number: "))

print(f"first number is {num1}, second number is {num2} and sum of these two numbers is {int(num1+num2)}")
# Out:
# Please enter first number:  21
# Please enter second number:  9
# first number is 21.0, second number is 9.0 and sum of these two numbers is 30

# %%
# String Properties
- char written inside quotes is a str
- str is a sequence data type-----> indexing and slicing is allowed on string
- str is a immutable data type

# %% [markdown]
# ![Screenshot (24).png](attachment:46b1ffe6-36f1-49d2-80f0-a5ac50d2d7d4.png)

# %%
a = "python"

# %%
id(a)
# Out:
# 2072422218992

# %%
a[0]
# Out:
# 'p'

# %%
a[1]
# Out:
# 'y'

# %%
a[2]
# Out:
# 't'

# %%
a[3]
# Out:
# 'h'

# %%
a[4]
# Out:
# 'o'

# %%
a[5]
# Out:
# 'n'

# %%
id(a[0])
# Out:
# 140735629041936

# %%
a = "python"
b = "cython"

# %%
Memory reusability ----> applicable

# %%
c = "usman"

# %%
a[5]
# Out:
# 'n'

# %%
c[4]
# Out:
# 'n'

# %%
id(a[5])
# Out:
# 140735629041840

# %%
id(c[4])
# Out:
# 140735629041840

# %%
WHen I am checking id(a) and id(b), 
it is giving some random number but when I am checking id(c), 
id(d) or id(p) it is showing syntax error, May I know why

# %%
id(a)
# Out:
# 2072422218992

# %%
id(b)
# Out:
# 2072430797200

# %%
id(c)
# Out:
# 2072514477728

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 d
#
# NameError: name 'd' is not defined

# %% [markdown]
# # indexing and Slicing

# %%
a = "python"

# %% [markdown]
# # Indexing
# - Positions of each char
# - we extract a single char using Indexing

# %% [markdown]
# ![image.png](attachment:496331a1-78c8-4587-bb6a-97b3b3794b63.png)

# %%
syntax of indexing
var_name[index_number]

# %%
a[4] # Positive
# Out:
# 'o'

# %%
a[2]
# Out:
# 't'

# %%
# negative ---> "y"
a[-5]
# Out:
# 'y'

# %%
a[-6]
# Out:
# 'p'

# %% [markdown]
# # Slicing

# %%
- extracting group of char together

# %%
lionel messi
Cristiano ronaldo

# %%
s = "lionel messi"

# %%
s[0:12:3]
# Out:
# 'ln s'

# %%
s[0:12:-2]
# Out:
# ''

# %% [markdown]
# ![image.png](attachment:6c40c1b4-63d0-4c9a-968a-4ef1bbf8ea5a.png)

# %%
s[1:-4:1]
# Out:
# 'ionel m'

# %%
s
# Out:
# 'lionel messi'

# %%
syntax
var_name[start_index:stop_index:step]

# %%
# +ve index number
s[2:4:]
# Out:
# 'on'

# %%
# +ve index number
s[2:5:]
# Out:
# 'one'

# %%
# +ve index number ----> "one"
s[-10:-7:]
# Out:
# 'one'

# %%
# mess
s[7:11:]
# Out:
# 'mess'

# %%
# mess ---> -ve
s[-5:-1:]
# Out:
# 'mess'

# %%
# ssi
# +ve
s[9:12:]
# Out:
# 'ssi'

# %%
s[9::]
# Out:
# 'ssi'

# %%
# -ve
s[-3::]
# Out:
# 'ssi'

# %%
# leno
# +ve
# -ve

# %%
s[5:1:]
# Out:
# ''

# %%
step

# %%
# note ---> default step size is +1( L to R)

# %%
# "one" +ve index number
s[2:5:1]
# Out:
# 'one'

# %%
s[5:1:1]
# Out:
# ''

# %%
s[5:1:-1]
# Out:
# 'leno'

# %%
s[0::]
# Out:
# 'lionel messi'

# %%
s[::]

# %%
default start if step is +1 ----> 0
default start if step is -1 ----> -1
0 to 12 ---> L to r
+1 ---> L to R

# %%
s[::]
# start ----> 0
# stop ---> end of the str
# step ---> +1(default step if not mentioned will be +1)
# Out:
# 'lionel messi'

# %%
s[::-1]
# start ----> -1
# stop ---> end of the str
# step ---> -1
# Out:
# 'issem lenoil'

# %%
s[::-1]
# Out:
# 'issem lenoil'

# %%
'lionel messi'
issem lenoil

# %%
# +ve
s[11::-1]
# Out:
# 'issem lenoil'

# %%
# -ve
s[-1::-1]
# Out:
# 'issem lenoil'

# %%
s[::-1]
# Out:
# 'issem lenoil'

# %%
email = "usman@gmail.com"

# %%
email[0:5:]
# Out:
# 'usman'

# %%
 s[4:10:3]
# Out:
# 'em'

# %%
l = ["usman@gmail.com" , "alex@gmail.com", "jon@gmail.com"]
name = [i.split("@")[0] for i in l ]
name
# Out:
# ['usman', 'alex', 'jon']

# %%
s = "lionel messi"

# %%
s[0:12:]
# Out:
# 'lionel messi'

# %%
s[0:12:2]

# %%
+2

# %%
s[-1:-13:]
# Out:
# ''

# %%
-1 -------->-13 ( Right to left)
+1 (Left to right)

# %%
s[-1:-13:-1]
# Out:
# 'issem lenoil'

# %%
s[0:12:1]
# Out:
# 'lionel messi'

# %%
s[0:100:]
# Out:
# 'lionel messi'

# %%
value = -1
s[-1:-9:value]
# Out:
# 'issem le'

# %%
name = "Menqa"

print(name[-4: -1])

print(name[1:4])
# Out:
# enq
# enq

# %%
a="salman"
a[3:-4:]
# Out:
# ''
